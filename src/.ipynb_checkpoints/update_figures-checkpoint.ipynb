# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas
import matplotlib.pyplot as plt
from collections import Counter, OrderedDict

# %%
from data import LaneData
data = LaneData('https://minigolf-live.com/turnier1304a/result.htm')
# Out:
# INIT DONE

# %%
#define the lanes for the CUP system
lanes_f = [ 'F'+str(i) for i in [2,4,7,8,12,13,15,17,18]]
lanes_e = [ 'E'+str(i) for i in [1,3,4,5,12,13,14,16,17 ]]

LANES_A_ALL = [ 'F'+str(i+1) for i in range(18)]
LANES_B_ALL = [ 'E'+str(i+1) for i in range(18)]  


LANES_A = lanes_f
LANES_B = lanes_e
# Out:
# ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15', 'E16', 'E17', 'E18', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18']

# %%
from bracket import RANK_W,RANK_M

# %%
from matchplay_MC import Cup_16, Cup_32
cup_W = Cup_16(RANK_W, data, LANES_A,LANES_B,mc_iter = 1000)
cup_W.plot()
# plt.savefig('../FIG/matchplay_W',bbox_inches = 'tight')

# %%
cup_M = Cup_32(RANK_M, data, LANES_A,LANES_B,mc_iter = 1000)
cup_M.plot()
# plt.savefig('../FIG/matchplay_M',bbox_inches = 'tight')
